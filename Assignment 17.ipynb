# %%
#Importing the Mushroom dataset 
import pandas as pd
df = pd.read_csv("mushroom.csv")
df
# Out:
#       Unnamed: 0 cap_shape cap_surface cap_color bruises     odor  \
# 0           1167    sunken       scaly     white      no    anise
# 1           1037    sunken     fibrous       red      no    anise
# 2            309      flat     grooves    purple     yes     foul
# 3            282      bell       scaly      pink     yes    fishy
# 4            820      flat      smooth    yellow     yes    musty
# ...          ...       ...         ...       ...     ...      ...
# 1995         863    sunken       scaly     brown     yes     foul
# 1996        1160    sunken       scaly    purple     yes    musty
# 1997         265    convex     grooves     green     yes    fishy
# 1998         411      bell      smooth     white      no  pungent
# 1999        1073    convex       scaly    yellow     yes  pungent
#
#      gill_attachment gill_spacing gill_size gill_color  ...  veil_type  \
# 0         descending      distant     broad       pink  ...    partial
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2000 non-null   int64
#  1   cap_shape                 2000 non-null   object
#  2   cap_surface               2000 non-null   object
#  3   cap_color                 2000 non-null   object
#  4   bruises                   2000 non-null   object
#  5   odor                      2000 non-null   object
#  6   gill_attachment           2000 non-null   object
#  7   gill_spacing              2000 non-null   object
#  8   gill_size                 2000 non-null   object
#  9   gill_color                2000 non-null   object
#  10  stalk_shape               2000 non-null   object
#  11  stalk_root                2000 non-null   object
#  12  stalk_surface_above_ring  2000 non-null   object
# ...

# %%
#ploting Histograms, box plots, or density plots to understand feature distributions
#Histograms, skewnwss, kurtosis for the numerical columns

# %%
df.hist("Unnamed: 0")
print("Skewdness of Unnamed: 0:",df['Unnamed: 0'].skew())
print("Kurtosis of Unnamed: 0:",df['Unnamed: 0'].kurt())
# Out:
# Skewdness of Unnamed: 0: 0.05242173576979329
# Kurtosis of Unnamed: 0: -1.2547263084662503

# %%
df.hist("stalk_height")
print("Skewdness of stalk_height",df['stalk_height'].skew())
print("Kurtosis of stalk_height",df['stalk_height'].kurt())
# Out:
# Skewdness of stalk_height 0.0383116032695003
# Kurtosis of stalk_height -1.1962983878077011

# %%
df.hist("cap_diameter")
print("Skewdness of cap_diameter:",df['cap_diameter'].skew())
print("Kurtosis of cap_diameter:",df['cap_diameter'].kurt())
# Out:
# Skewdness of cap_diameter: 0.10759489701255188
# Kurtosis of cap_diameter: -1.2438477218993156

# %%
#Ploting Boxplot for numerical columns and observing outliers and inter quartile ranges

# %%
df.boxplot(column='Unnamed: 0',vert=False)
import numpy as np
q1 = np.percentile(df["Unnamed: 0"],25)
print("25th percentile",q1)
q3 = np.percentile(df["Unnamed: 0"],75)
print("75th percentile",q3)
iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)
print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["Unnamed: 0"][df["Unnamed: 0"] > UW]))
LW = q1 - (1.5*iqr)
print("Lower whisker length:",LW)
print("number of outliers lesser than lower whisker:",len(df["Unnamed: 0"][df["Unnamed: 0"] < LW]))

#Observations:

#1.Since the boxplot is at the center of the region we may assume it follows uunder normal distribution.
#2.And also it was showing outliers are 0.
# Out:
# 25th percentile 290.0
# 75th percentile 957.25
# Inter quartile range: 667.25
# Upper whisker length: 1958.125
# number of outliers greater than upper whisker: 0
# Lower whisker length: -710.875
# number of outliers lesser than lower whisker: 0

# %%
df.boxplot(column='stalk_height',vert=False)
import numpy as np
q1 = np.percentile(df["stalk_height"],25)
print("25th percentile",q1)
q3 = np.percentile(df["stalk_height"],75)
print("75th percentile",q3)
iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)
print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["stalk_height"][df["stalk_height"] > UW]))
LW = q1 - (1.5*iqr)
print("Lower whisker length:",LW)
print("number of outliers lesser than lower whisker:",len(df["stalk_height"][df["stalk_height"] < LW]))

#Observations:

#1.Since the boxplot is at the center of the region we may assume it follows uunder normal distribution.
#2.And also it was showing outliers are 0.
# Out:
# 25th percentile 5.2910089106810005
# 75th percentile 11.781272039772865
# Inter quartile range: 6.490263129091865
# Upper whisker length: 21.516666733410663
# number of outliers greater than upper whisker: 0
# Lower whisker length: -4.444385782956797
# number of outliers lesser than lower whisker: 0

# %%
df.boxplot(column='cap_diameter',vert=False)
import numpy as np
q1 = np.percentile(df["cap_diameter"],25)
print("25th percentile",q1)
q3 = np.percentile(df["cap_diameter"],75)
print("75th percentile",q3)
iqr = q3-q1
print("Inter quartile range:",iqr)
UW = q3 + (1.5*iqr)
print("Upper whisker length:",UW)
print("number of outliers greater than upper whisker:",len(df["cap_diameter"][df["cap_diameter"] > UW]))
LW = q1 - (1.5*iqr)
print("Lower whisker length:",LW)
print("number of outliers lesser than lower whisker:",len(df["cap_diameter"][df["cap_diameter"] < LW]))

#Observations:

#1.Since the boxplot is at the center of the region we may assume it follows uunder normal distribution.
#2.And also it was showing outliers are 0.
# Out:
# 25th percentile 5.7235209505112845
# 75th percentile 18.69860549814206
# Inter quartile range: 12.975084547630777
# Upper whisker length: 38.16123231958822
# number of outliers greater than upper whisker: 0
# Lower whisker length: -13.73910587093488
# number of outliers lesser than lower whisker: 0

# %%
#Density plots is useful for visualizing the distribution of a single continuous variable

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.kdeplot(df['Unnamed: 0'], shade=True)
plt.title('Density Plot for Unnamed: 0')
plt.xlabel('Unnamed: 0')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_13756\943956199.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['Unnamed: 0'], shade=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.kdeplot(df['stalk_height'], shade=True)
plt.title('Density Plot for stalk_height')
plt.xlabel('stalk_height')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_13756\909845173.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['stalk_height'], shade=True)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.kdeplot(df['cap_diameter'], shade=True)
plt.title('Density Plot for cap_diameter')
plt.xlabel('cap_diameter')
plt.ylabel('Density')
plt.show()
# Out:
# C:\Users\pc\AppData\Local\Temp\ipykernel_13756\2517641789.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df['cap_diameter'], shade=True)

# %%
##Steps for Investigating Feature Correlations
##Calculating the Correlation Matrix:

#The correlation matrix is a table showing correlation coefficients between variables. 

#The coefficient values range from -1 to 1.

#1 indicates that a perfect positive correlation.
#0 means no correlation.
#-1 indicating that a perfect negative correlation.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import LabelEncoder

# from sklearn.preprocessing import LabelEncoder
mushroom_data = pd.read_csv('mushroom.csv')


# Encoding all categorical features
encoded_data = mushroom_data.apply(LabelEncoder().fit_transform)

# Calculate the correlation matrix
correlation_matrix = encoded_data.corr()

# Ploting the heatmap
plt.figure(figsize=(12, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', center=0)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %%
#Interpretations:

#Strong Positive Correlation: 

#If two features have a correlation close to 1, it means that as one feature increases, the other feature also being increased.

#Strong Negative Correlation: 
#If two features have a correlation close to -1, it means that as one feature will be increases, then the other feature is being decreased.

#Weak or No Correlation: 
#If the correlation is close to 0, it means there is little or ot be no linear relationship between the features.

# %%
#Encode categorical variables if necessary.
#Split the dataset into training and testing sets

# %%
from sklearn.preprocessing import StandardScaler
SS = StandardScaler()
df_num = SS.fit_transform(df[['stalk_height','cap_diameter','Unnamed: 0']])
df_num = pd.DataFrame(df_num)
df_num.columns = ['stalk_height','cap_diameter','Unnamed: 0']
df_num.head()
# Out:
#    stalk_height  cap_diameter  Unnamed: 0
# 0      1.576459     -1.030123    1.445410
# 1     -1.216463      0.958407    1.098741
# 2      0.163717     -0.724904   -0.842601
# 3     -0.871852      1.222967   -0.914602
# 4      1.511897      0.032765    0.520072

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 26 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Unnamed: 0                2000 non-null   int64
#  1   cap_shape                 2000 non-null   object
#  2   cap_surface               2000 non-null   object
#  3   cap_color                 2000 non-null   object
#  4   bruises                   2000 non-null   object
#  5   odor                      2000 non-null   object
#  6   gill_attachment           2000 non-null   object
#  7   gill_spacing              2000 non-null   object
#  8   gill_size                 2000 non-null   object
#  9   gill_color                2000 non-null   object
#  10  stalk_shape               2000 non-null   object
#  11  stalk_root                2000 non-null   object
#  12  stalk_surface_above_ring  2000 non-null   object
# ...

# %%
from sklearn.preprocessing import  LabelEncoder
LE = LabelEncoder()
df_cat = df[["cap_shape","cap_surface","cap_color","bruises","odor","gill_attachment","gill_spacing","gill_size","gill_color","stalk_shape","stalk_root","stalk_surface_above_ring","stalk_surface_below_ring","stalk_color_above_ring","stalk_color_below_ring","veil_type","veil_color","ring_number","ring_type","spore_print_color","population","habitat","class"]]

# %%
df_cat["cap_shape"] = LE.fit_transform(df_cat[["cap_shape"]])
df_cat["cap_surface"] = LE.fit_transform(df_cat[["cap_surface"]])
df_cat["cap_color"] = LE.fit_transform(df_cat[["cap_color"]])
df_cat["bruises"] = LE.fit_transform(df_cat[["bruises"]])
df_cat["odor"] = LE.fit_transform(df_cat[["odor"]])
df_cat["gill_attachment"] = LE.fit_transform(df_cat[["gill_attachment"]])
df_cat["gill_spacing"] = LE.fit_transform(df_cat[["gill_spacing"]])
df_cat["gill_size"] = LE.fit_transform(df_cat[["gill_size"]])
df_cat["gill_color"] = LE.fit_transform(df_cat[["gill_color"]])
df_cat["stalk_shape"] = LE.fit_transform(df_cat[["stalk_shape"]])
df_cat["stalk_root"] = LE.fit_transform(df_cat[["stalk_root"]])
df_cat["stalk_surface_above_ring"] = LE.fit_transform(df_cat[["stalk_surface_above_ring"]])
df_cat["stalk_surface_below_ring"] = LE.fit_transform(df_cat[["stalk_surface_below_ring"]])
df_cat["stalk_color_above_ring"] = LE.fit_transform(df_cat[["stalk_color_above_ring"]])
df_cat["stalk_color_below_ring"] = LE.fit_transform(df_cat[["stalk_color_below_ring"]])
df_cat["veil_type"] = LE.fit_transform(df_cat[["veil_type"]])
df_cat["veil_color"] = LE.fit_transform(df_cat[["veil_color"]])
df_cat["ring_number"] = LE.fit_transform(df_cat[["ring_number"]])
df_cat["ring_type"] = LE.fit_transform(df_cat[["ring_type"]])
df_cat["spore_print_color"] = LE.fit_transform(df_cat[["spore_print_color"]])
df_cat["population"] = LE.fit_transform(df_cat[["population"]])
df_cat["habitat"] = LE.fit_transform(df_cat[["habitat"]])
df_cat["class"] = LE.fit_transform(df_cat[["class"]])
df_cat.head()
# Out:
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\pc\AppData\Local\Temp\ipykernel_13756\4241823617.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cat["cap_shape"] = LE.fit_transform(df_cat[["cap_shape"]])
# C:\Users\pc\anaconda3\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# ...

# %%
df_new = pd.concat([df_num,df_cat],axis=1)
df_new
# Out:
#       stalk_height  cap_diameter  Unnamed: 0  cap_shape  cap_surface  \
# 0         1.576459     -1.030123    1.445410          4            2
# 1        -1.216463      0.958407    1.098741          4            0
# 2         0.163717     -0.724904   -0.842601          3            1
# 3        -0.871852      1.222967   -0.914602          0            2
# 4         1.511897      0.032765    0.520072          3            3
# ...            ...           ...         ...        ...          ...
# 1995     -0.695623      0.730771    0.634739          4            2
# 1996     -0.527090      0.168525    1.426743          4            2
# 1997      1.382181     -0.148193   -0.959935          2            1
# 1998      0.715199     -0.552164   -0.570600          0            3
# 1999      1.249170      1.240556    1.194742          2            2
#
#       cap_color  bruises  odor  gill_attachment  gill_spacing  ...  \
# 0             7        0     1                1             2  ...
# ...

# %%
df_new.shape
# Out:
# (2000, 26)

# %%
X = df_new.iloc[:,0:24]
X.head()
# Out:
#    stalk_height  cap_diameter  Unnamed: 0  cap_shape  cap_surface  cap_color  \
# 0      1.576459     -1.030123    1.445410          4            2          7
# 1     -1.216463      0.958407    1.098741          4            0          6
# 2      0.163717     -0.724904   -0.842601          3            1          5
# 3     -0.871852      1.222967   -0.914602          0            2          4
# 4      1.511897      0.032765    0.520072          3            3          8
#
#    bruises  odor  gill_attachment  gill_spacing  ...  \
# 0        0     1                1             2  ...
# 1        0     1                3             1  ...
# 2        1     4                1             1  ...
# 3        1     3                3             0  ...
# 4        1     5                2             1  ...
#
#    stalk_surface_above_ring  stalk_surface_below_ring  stalk_color_above_ring  \
# 0                         3                         2                       3
# ...

# %%
Y = df["class"]
Y.shape
# Out:
# (2000,)

# %%
#1.Employ scatter plots, pair plots, or relevant visualizations to comprehend feature distributions and relationships.
#2.Visualize class distributions to gauge dataset balance or imbalance.

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Unnamed: 0', y='stalk_height', data=encoded_data)
plt.title('Scatter Plot between Feature 1 and Feature 2 x=Unnamed: 0, y=stalk_height')
plt.xlabel('Unnamed: 0')
plt.ylabel('stalk_height')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='Unnamed: 0', y='cap_diameter', data=encoded_data)
plt.title('Scatter Plot between Feature 1 and Feature 2 that is x=Unnamed: 0, y=cap_diameter')
plt.xlabel('Unnamed: 0')
plt.ylabel('cap_diameter')
plt.show()

# %%
plt.figure(figsize=(10, 6))
sns.scatterplot(x='stalk_height', y='cap_diameter', data=encoded_data)
plt.title('Scatter Plot between Feature 1 and Feature 2 that is x=stalk_height, y=cap_diameter')
plt.xlabel('stalk_height')
plt.ylabel('cap_diameter')
plt.show()

# %%
#1.Implement a basic SVM classifier using Python libraries like scikit-learn.
#2.Train the SVM model on the training data.
#.Evaluate model performance on the testing data using appropriate metrics (e.g., accuracy, precision, recall, F1-score).

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size=0.25)

# %%
from sklearn.svm import SVC

model = SVC(kernel='linear')

model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test  = model.predict(X_test)

#metrice
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(Y_train,Y_pred_train)
print("Training Accuracy score:" , ac1.round(3))
ac2 = accuracy_score(Y_test,Y_pred_test)
print("Test Accuracy score:" , ac2.round(3))
# Out:
# Training Accuracy score: 0.703
# Test Accuracy score: 0.692

# %%
# cross validation
#=========================================================

training_acc = []
test_acc = []

for i in range(1,100):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3,random_state=i)
    model.fit(X_train.values,Y_train)
    Y_pred_train = model.predict(X_train.values)
    Y_pred_test  = model.predict(X_test.values)
    training_acc.append(accuracy_score(Y_train,Y_pred_train))
    test_acc.append(accuracy_score(Y_test,Y_pred_test))

import numpy as np
print("Cross validation - Training accuracy:" ,np.mean(training_acc).round(2))
print("Cross validation - Test accuracy:" ,np.mean(test_acc).round(2))
# Out:
# Cross validation - Training accuracy: 0.7
# Cross validation - Test accuracy: 0.7

# %%
from sklearn.svm import SVC

model = SVC(kernel='poly',degree=2)

model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test  = model.predict(X_test)

#metrice
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(Y_train,Y_pred_train)
print("Training Accuracy score:" , ac1.round(3))
ac2 = accuracy_score(Y_test,Y_pred_test)
print("Test Accuracy score:" , ac2.round(3))
# Out:
# Training Accuracy score: 0.714
# Test Accuracy score: 0.698

# %%
# cross validation
#=========================================================

training_acc = []
test_acc = []

for i in range(1,100):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3,random_state=i)
    model.fit(X_train.values,Y_train)
    Y_pred_train = model.predict(X_train.values)
    Y_pred_test  = model.predict(X_test.values)
    training_acc.append(accuracy_score(Y_train,Y_pred_train))
    test_acc.append(accuracy_score(Y_test,Y_pred_test))

import numpy as np
print("Cross validation - Training accuracy:" ,np.mean(training_acc).round(2))
print("Cross validation - Test accuracy:" ,np.mean(test_acc).round(2))
# Out:
# Cross validation - Training accuracy: 0.7
# Cross validation - Test accuracy: 0.7

# %%
from sklearn.svm import SVC

model = SVC(kernel='poly',degree=3)

model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test  = model.predict(X_test)

#metrice
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(Y_train,Y_pred_train)
print("Training Accuracy score:" , ac1.round(3))
ac2 = accuracy_score(Y_test,Y_pred_test)
print("Test Accuracy score:" , ac2.round(3))
# Out:
# Training Accuracy score: 0.795
# Test Accuracy score: 0.737

# %%
# cross validation
#=========================================================

training_acc = []
test_acc = []

for i in range(1,100):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3,random_state=i)
    model.fit(X_train.values,Y_train)
    Y_pred_train = model.predict(X_train.values)
    Y_pred_test  = model.predict(X_test.values)
    training_acc.append(accuracy_score(Y_train,Y_pred_train))
    test_acc.append(accuracy_score(Y_test,Y_pred_test))

import numpy as np
print("Cross validation - Training accuracy:" ,np.mean(training_acc).round(2))
print("Cross validation - Test accuracy:" ,np.mean(test_acc).round(2))

# %%
from sklearn.svm import SVC

model = SVC(kernel='poly',degree=4)

model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test  = model.predict(X_test)

#metrice
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(Y_train,Y_pred_train)
print("Training Accuracy score:" , ac1.round(3))
ac2 = accuracy_score(Y_test,Y_pred_test)
print("Test Accuracy score:" , ac2.round(3))

# %%
# cross validation
#=========================================================

training_acc = []
test_acc = []

for i in range(1,100):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3,random_state=i)
    model.fit(X_train.values,Y_train)
    Y_pred_train = model.predict(X_train.values)
    Y_pred_test  = model.predict(X_test.values)
    training_acc.append(accuracy_score(Y_train,Y_pred_train))
    test_acc.append(accuracy_score(Y_test,Y_pred_test))

import numpy as np
print("Cross validation - Training accuracy:" ,np.mean(training_acc).round(2))
print("Cross validation - Test accuracy:" ,np.mean(test_acc).round(2))

# %%
from sklearn.svm import SVC

model = SVC(kernel='poly',degree=5)

model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test  = model.predict(X_test)

#metrice
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(Y_train,Y_pred_train)
print("Training Accuracy score:" , ac1.round(3))
ac2 = accuracy_score(Y_test,Y_pred_test)
print("Test Accuracy score:" , ac2.round(3))

# %%
# cross validation
#=========================================================

training_acc = []
test_acc = []

for i in range(1,100):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3,random_state=i)
    model.fit(X_train.values,Y_train)
    Y_pred_train = model.predict(X_train.values)
    Y_pred_test  = model.predict(X_test.values)
    training_acc.append(accuracy_score(Y_train,Y_pred_train))
    test_acc.append(accuracy_score(Y_test,Y_pred_test))

import numpy as np
print("Cross validation - Training accuracy:" ,np.mean(training_acc).round(2))
print("Cross validation - Test accuracy:" ,np.mean(test_acc).round(2))

# %%
from sklearn.svm import SVC

model = SVC(kernel='poly',degree=6)

model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test  = model.predict(X_test)

#metrice
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(Y_train,Y_pred_train)
print("Training Accuracy score:" , ac1.round(3))
ac2 = accuracy_score(Y_test,Y_pred_test)
print("Test Accuracy score:" , ac2.round(3))

# %%
# cross validation
#=========================================================

training_acc = []
test_acc = []

for i in range(1,100):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3,random_state=i)
    model.fit(X_train.values,Y_train)
    Y_pred_train = model.predict(X_train.values)
    Y_pred_test  = model.predict(X_test.values)
    training_acc.append(accuracy_score(Y_train,Y_pred_train))
    test_acc.append(accuracy_score(Y_test,Y_pred_test))

import numpy as np
print("Cross validation - Training accuracy:" ,np.mean(training_acc).round(2))
print("Cross validation - Test accuracy:" ,np.mean(test_acc).round(2))

# %%
from sklearn.svm import SVC

model = SVC(kernel='poly',degree=7)

model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test  = model.predict(X_test)

#metrice
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(Y_train,Y_pred_train)
print("Training Accuracy score:" , ac1.round(3))
ac2 = accuracy_score(Y_test,Y_pred_test)
print("Test Accuracy score:" , ac2.round(3))

# %%
# cross validation
#=========================================================

training_acc = []
test_acc = []

for i in range(1,100):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3,random_state=i)
    model.fit(X_train.values,Y_train)
    Y_pred_train = model.predict(X_train.values)
    Y_pred_test  = model.predict(X_test.values)
    training_acc.append(accuracy_score(Y_train,Y_pred_train))
    test_acc.append(accuracy_score(Y_test,Y_pred_test))

import numpy as np
print("Cross validation - Training accuracy:" ,np.mean(training_acc).round(2))
print("Cross validation - Test accuracy:" ,np.mean(test_acc).round(2))

# %%
from sklearn.svm import SVC

model = SVC(kernel='rbf',gamma='scale')  

model.fit(X_train,Y_train)
Y_pred_train = model.predict(X_train)
Y_pred_test  = model.predict(X_test)

#metrice
from sklearn.metrics import accuracy_score
ac1 = accuracy_score(Y_train,Y_pred_train)
print("Training Accuracy score:" , ac1.round(3))
ac2 = accuracy_score(Y_test,Y_pred_test)
print("Test Accuracy score:" , ac2.round(3))

# %%
# cross validation
#=========================================================

training_acc = []
test_acc = []

for i in range(1,100):
    X_train,X_test,Y_train,Y_test = train_test_split(X,Y, test_size=0.3,random_state=i)
    model.fit(X_train.values,Y_train)
    Y_pred_train = model.predict(X_train.values)
    Y_pred_test  = model.predict(X_test.values)
    training_acc.append(accuracy_score(Y_train,Y_pred_train))
    test_acc.append(accuracy_score(Y_test,Y_pred_test))

import numpy as np
print("Cross validation - Training accuracy:" ,np.mean(training_acc).round(2))
print("Cross validation - Test accuracy:" ,np.mean(test_acc).round(2))

# %%
#Evaluating model performance on the testing data using appropriate metrics (e.g., accuracy, precision, recall, F1-score).

# %%
#metrics
from sklearn.metrics import confusion_matrix,accuracy_score
cm = confusion_matrix(Y_test,Y_pred_test)
cm

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(10, 7))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix')
plt.show()

# %%
# Calculate accuracy
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score, classification_report
accuracy = accuracy_score(Y_test,Y_pred_test)

# Calculate precision, recall, and F1-score for each class
precision = precision_score(Y_test,Y_pred_test,average='weighted')
recall = recall_score(Y_test,Y_pred_test, average='weighted')
f1 = f1_score(Y_test,Y_pred_test, average='weighted')

# Print the evaluation metrics
print(f"Accuracy: {accuracy:.2f}")
print(f"Precision: {precision:.2f}")
print(f"Recall: {recall:.2f}")
print(f"F1 Score: {f1:.2f}")

# Detailed classification report
print("\nClassification Report:\n", classification_report(Y_test,Y_pred_test))

# %%
import pandas as pd
import numpy as np
from sklearn.svm import SVC
from sklearn.preprocessing import LabelEncoder
from mlxtend.plotting import plot_decision_regions
import matplotlib.pyplot as plt

# Sample data (replace with your actual DataFrame)
df_new = pd.DataFrame({
    'feature1': np.random.rand(100),
    'feature2': np.random.rand(100),
    'feature3': np.random.rand(100),
    'class': np.random.choice(['class1', 'class2'],100)
})

# Extract features and target
X = df_new[['feature1', 'feature2', 'feature3']]
Y = df_new['class']

# Convert target variable to integer labels
le = LabelEncoder()
Y_encoded = le.fit_transform(Y)

# Train an SVM classifier
model = SVC(kernel='linear')
model.fit(X, Y_encoded)

# Define filler values
filler_values = {2: X['feature3'].mean()}  # Fix feature3 at its mean value

# Plot decision regions
plt.figure(figsize=(10, 7))
plot_decision_regions(X=X.values, 
                      y=Y_encoded, 
                      clf=model, 
                      legend=2, 
                      filler_feature_values=filler_values, 
                      filler_feature_ranges={2: 0.1})

plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.title('SVM Decision Regions with Filler Values')
plt.show()

# %%
#Comparison and Analysis
#Compare SVM performance with various kernels (e.g., linear, polynomial, radial basis function).

#CROSS VALIDATION RESULTS:

#METHOD		TRAIN	TEST
#LINEAR		 70      70

#POLY
#DEGREE=2	 70	      70

#POLY
#DEGREE=3	79	    73

#POLY 
#DEGREE=4	88       77

#POLY 
#DEGREE=5	95	    81

#POLY
#DEGREE=6	97	    88

#POLY
#DEGREE=7   98      83

#RBF		71	     7

# %%
#Analyze SVM strengths and weaknesses for the Mushroom dataset based on EDA and visualization results.

#Effective for High-Dimensional Data: The mushroom dataset may be converted into a high-dimensional space using label encoding, 
#making SVM useful in high-dimensional domains.
         
##Memory Efficiency: SVM is memory efficient since it employs a subset of training points in the support vectors.
         
#Versatility: SVM can adapt to different kinds of data and classification tasks owing to its different kernel functions (linear, polynomial, and RBF).
         
#Weaknesses:

#Computationally Intensive: Training time can be significant for large datasets, especially with non-linear kernels.

#LESS Effective with Noisy Data: SVM's sensitivity to noise may have an impact on performance as a whole.
                                               
#Feature Scaling Is Necessary: SVM models need feature scaling in order to verify if each feature contributes equally to the decision boundary.

                                               
#Practical Implications of SVM in Real-World Classification Tasks                                           

#Advantages:

#Robustness to Overfitting: Especially with high-dimensional data, SVM is less prone to overfitting compared to other classifiers, 
#particularly when the number of dimensions exceeds the number of samples.
                                               
#Flexibility with Kernels: The ability to choose different kernels makes SVM highly versatile and capable of handling a variety of data distributions.
                                               
#HIGH Accuracy: SVM often provides high accuracy for binary and multi-class classification tasks, 
#making it suitable for critical applications such as disease diagnosis, fraud detection, and text classification.
                                               
#Disadvantages:

#Performance on Large Datasets: SVMs can be computationally expensive and time-consuming on large datasets, 
#which can limit their applicability in big data scenarios
                                               
#Parameter Tuning: SVM requires careful tuning of parameters (like C and gamma) and kernel choice, 
#which can be challenging and time-consuming.

                                               
#Interpretability: The decision function of SVM, especially with non-linear kernels, can be difficult to interpret, 
#which might be a drawback in applications requiring clear explanations of the model's decisions.

                                               
#In the view of the mushroom dataset, SVM can effectively classify mushrooms as edible or poisonous.
                                                                       
#However, careful preprocessing, parameter tuning, and consideration of computational resources are essential for optimal performance.

# %%
#Discuss practical implications of SVM in real-world classification tasks.
#Advantages:

#Effective in High Dimensions: SVMs perform well in high-dimensional spaces.

#Versatile with Kernels: The kernel trick allows them to handle non-linear relationships.

#Robustness to Overfitting: SVMs have good generalization capabilities with proper parameter tuning.

#Challenges:

#Computational Complexity: Training can be slow for large datasets.

#Parameter Tuning: Requires careful tuning of parameters (e.g., kernel choice, regularization parameter) which can be complex and time-consuming.

#Interpretability: SVMs can be less interpretable compared to some other models like decision trees.

#In conclusion, SVMs are a versatile and powerful tool for classification tasks in various real-world applications. Their ability to handle high-dimensional data and complex boundaries makes them suitable for many practical scenarios, despite some challenges related to computational complexity and parameter tuning.
